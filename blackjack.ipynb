# %%
import random
#global
jugando=True
turno=True
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}
class Card():
    def __init__(self,tipo,valor):
        self.tipo=tipo
        self.valor=valor
    def __str__(self):
        return self.valor+ " de "+ self.tipo
class Deck():
    def __init__(self):
        self.deck=[]
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    def __str__(self):
        compmazo=''
        for carta in self.deck:
            compmazo+='\n' + carta.__str__()
        return compmazo
    def mezclar(self):
        random.shuffle(self.deck)
class Mano():
    def __init__(self,Deck):
        self.mano=[]
        self.mano.append(Deck.deck.pop(0))
        self.mano.append(Deck.deck.pop(0))
       
    def __str__(self):
        lacartaes=''
        for carta in self.mano:
            lacartaes+= carta.__str__()+ '\n'
        return lacartaes
    def tomarcarta(self,Deck):
        tetoca=Deck.deck.pop(0)
        self.mano.append(tetoca)
        contar1=0
        for carta in self.mano:
            contar1+=values[carta.valor]
            
        if contar1<21:
            
            print('hasta ahora tienes {} y te toco'.format(contar1,tetoca))
            return contar1
        else:
            print('perdiste {} te toco {}'.format(contar1,tetoca))
            turno=False
            return contar1
            
        
class apuesta():
    def __init_(self,bet):
        self.bet=bet

class jugador():
    def __init__(self,nombre,fichas=100):
        self.nombre=nombre
        self.fichas=fichas

#Juego


def tomarapuesta(jugador):
    while True:
        try:
            apuestapasada=int(input('Introduzca apuesta \n'))
            
        except:
            print('Que sea un entero esta vez')
        else:
            if apuestapasada>jugador.fichas:
                print(' no te da el cash te quedan {}'.format(jugador.fichas))
            else:
                break
print('Bienvenido a Black Jack')

while jugando==True:
    jugador1=jugador('jugador1')
    jugador2=jugador('dealer')
    tomarapuesta(jugador1)
    print ('genial')
    deck1=Deck()
    deck1.mezclar()
    mano1=Mano(deck1)
    print('\n .Cartas del jugador:')
    print(mano1)
    mano2=Mano(deck1)
    print('\n .Cartas del dealer:')
    print( mano2.mano[0])
    print('')
    while turno==True:
        try:
            sino=str(input('¿Desea tomar otra carta?'))
        except:
            print('ingrese una letra')
        else:
            if sino=='s':
                mano1.tomarcarta(deck1)
                continue
            else:
                print('Turno del dealer')
                turno=False
                break
        
    while turno==False:
        contar=0
        for carta in mano2:
            contar+=values[carta.valor]
        if contar<17:
            continue
        else:
            turno=True
        self.mano.append(Deck.deck.pop(0))
        print('dealer?')
        
    if contar<21 and contar>contar1:
        print('gano el dealer')
  
        
    
    
        
    
print('\n fin')
# Out:
# Bienvenido a Black Jack
# Introduzca apuesta
# 10
# genial
#
#  .Cartas del jugador:
# Four de Spades
# Five de Spades
#
#
#  .Cartas del dealer:
# Ten de Clubs
#
# ¿Desea tomar otra carta?s
# hasta ahora tienes 16 y te toco
